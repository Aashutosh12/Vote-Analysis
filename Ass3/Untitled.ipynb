# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.utils import resample

# %%
df=pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      Pedigree  Age  Outcome
# 0       0.627   50        1
# 1       0.351   31        0
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      Pedigree  Age  Outcome
# 0       0.627   50        1
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies      0
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# Insulin          0
# BMI              0
# Pedigree         0
# Age              0
# Outcome          0
# dtype: int64

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x=df['Outcome'])
# Out:
# <Axes: xlabel='Outcome', ylabel='count'>

# %%
one=df[df['Outcome']==1]
zero=df[df['Outcome']==0]

# %%
one_upsample=resample(one,replace=True,n_samples=int(0.8*(len(zero))),random_state=42)

# %%
new_df=pd.concat([zero,one_upsample])

# %%
new_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 630            7      114             64              0        0  27.4
# 716            3      173             78             39      185  33.8
# 425            4      184             78             39      277  37.0
# 541            3      128             72             25      190  32.4
# 662            8      167            106             46      231  37.6
#
#      Pedigree  Age  Outcome
# 1       0.351   31        0
# 3       0.167   21        0
# ...

# %%
new_df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    400
# Name: count, dtype: int64

# %%
new_df.sample(frac=1)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 302            5       77             82             41       42  35.8
# 307            0      137             68             14      148  24.8
# 330            8      118             72             19        0  23.1
# 619            0      119              0              0        0  32.4
# 120            0      162             76             56      100  53.2
# ..           ...      ...            ...            ...      ...   ...
# 696            3      169             74             19      125  29.9
# 238            9      164             84             21        0  30.8
# 160            4      151             90             38        0  29.7
# 113            4       76             62              0        0  34.0
# 313            3      113             50             10       85  29.5
#
#      Pedigree  Age  Outcome
# 302     0.156   35        0
# 307     0.143   21        0
# ...
